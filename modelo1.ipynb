# %%
print("Aló jupyter")
# Out:
# Aló jupyter

# %%
#Serve para listar a biblioteca instalada
! pip list
# Out:
# Package                 Version
# ----------------------- --------------
# asttokens               3.0.0
# async-lru               2.0.5
# attrs                   25.3.0
# babel                   2.17.0
# bleach                  6.2.0
# certifi                 2025.8.3
# charset-normalizer      3.4.3
# colorama                0.4.6
# comm                    0.2.3
# debugpy                 1.8.16
# decorator               5.2.1
# defusedxml              0.7.1
# executing               2.2.1
# fastjsonschema          2.21.2
# fqdn                    1.5.1
# h11                     0.16.0
# idna                    3.10
# ipykernel               6.30.1
# ipython                 9.5.0
# ipython_pygments_lexers 1.1.1
# jedi                    0.19.2
# Jinja2                  3.1.6
# joblib                  1.5.2
# json5                   0.12.1
# jsonpointer             3.0.0
# jupyter_client          8.6.3
# jupyter_core            5.8.1
# jupyterlab_pygments     0.3.0
# ...

# %%
! pip install scikit-learn
# Out:
# ...
#    ---------------------------------------- 0.0/8.7 MB ? eta -:--:--
#    -------- ------------------------------- 1.8/8.7 MB 8.0 MB/s eta 0:00:01
#    ------------- -------------------------- 2.9/8.7 MB 6.5 MB/s eta 0:00:01
#    ---------------- ----------------------- 3.7/8.7 MB 6.0 MB/s eta 0:00:01
#    --------------------- ------------------ 4.7/8.7 MB 5.5 MB/s eta 0:00:01
#    ------------------------- -------------- 5.5/8.7 MB 5.2 MB/s eta 0:00:01
#    ------------------------------ --------- 6.6/8.7 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.6/8.7 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------  8.7/8.7 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------- 8.7/8.7 MB 4.9 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    ---- ----------------------------------- 1.3/12.8 MB 6.2 MB/s eta 0:00:02
#    -------- ------------------------------- 2.6/12.8 MB 6.4 MB/s eta 0:00:02
# ...

# %%
# serve para salvar as biliotecas... em caso de formatação de máquina ou perdeu os arquivos 
! pip freeze > requirements.txt

# %%
"""biblioteca padrão de ciência de dados o professor usou para buscar dados da internet, muito popular na ciência da computação"""
! pip install pandas

# %%
#Serve para listar a biblioteca instalada
! pip list
# Out:
# Package                 Version
# ----------------------- --------------
# asttokens               3.0.0
# async-lru               2.0.5
# attrs                   25.3.0
# babel                   2.17.0
# bleach                  6.2.0
# certifi                 2025.8.3
# charset-normalizer      3.4.3
# colorama                0.4.6
# comm                    0.2.3
# debugpy                 1.8.16
# decorator               5.2.1
# defusedxml              0.7.1
# executing               2.2.1
# fastjsonschema          2.21.2
# fqdn                    1.5.1
# h11                     0.16.0
# idna                    3.10
# ipykernel               6.30.1
# ipython                 9.5.0
# ipython_pygments_lexers 1.1.1
# jedi                    0.19.2
# Jinja2                  3.1.6
# joblib                  1.5.2
# json5                   0.12.1
# jsonpointer             3.0.0
# jupyter_client          8.6.3
# jupyter_core            5.8.1
# jupyterlab_pygments     0.3.0
# ...

# %%
#features = caracteristicas 
#pelo longo
#perna curta
#faz au au 

#Dados de treino : X
porco1 = [1,1,0]
porco2 = [0,1,1]
porco3 = [0,1,0]

cachorr01 = [0,1,1]
cachorro2 = [1,1,1]
cachorro3 = [0,0,1]
